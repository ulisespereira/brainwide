# %%
from classes.connectivity_blocks import *
from classes.network_dynamics import *
from classes.task import *
import scipy.io as sio
import pickle
import pandas as pd

import matplotlib as mpl
new_rc_params = {'text.usetex': False,
"svg.fonttype": 'none'
}
mpl.rcParams.update(new_rc_params)

# %%
def model_parameters():
    modelparams = dict(
            seed = 4,
            #network parameters
            n_ctx = 89,
            N_block = 400, #neurons per region
            N_recorded = 150, #neurons recorded per region

            #transfer function Pereira&Brunel,18
            rm = 1,#76.2,
            beta = 1, #Pereira&Brunel
            h0 = .1,
            amp_offset = 1,

            #dynamics excitatory
            tau_ctx =  60 * 1e-3,#s mainly NMDA

            #private noise 
            sigma_noise = 0,

            #Low-d noise
            sigma_ld = 22,
            tau_ld = 100 * 1e-3,
            mu_ld = 0,
            
            #spines dependencies
            A_spines = 1,#10
            offset_spines = .1,
            
            #noise
            amp_loc_noise = 0.1,#0.0, #amp noise local dorsal
            amp_lr_noise = 0.1,#0.0, #ventral<->ventral amp noise long-range

            #hebbian 
            amp_loc = 0,
            amp_lr = 0,

            #stimulation parameters
            period = 10., # 20 seconds
            dt = 15. * 1e-3,# indegration time
            t_stim = .5, #period-t_stim when stimulus
            t_start = 2.5, #t_starts
            g_p= 1.5
            
            )
    return modelparams

# %%
def loading_matrices(gamma, path=''):
    ''' this functions load the matrices and normalize them'''
    PATH = path + 'connectivity_data/'
    tract = sio.loadmat(PATH + 'FSe_tractography.mat')
    names_ctx = [tract['area_list_Sean_89'][0][l][0] for l in range(89)] 
    fln = pickle.load(open(PATH + 'mat_tractography.p','rb'))
    hier_tract =sio.loadmat(PATH + 'hierarchy_89_areas.mat')
    hierarchy = np.array([x for x in hier_tract['hierarchy_vals_fullgraph'][:,0]])
    t1_t2 = sio.loadmat(PATH + 'myelin_hierarchy_order.mat')
    t1_t2_val = t1_t2['myelin_hierarchy_order'][:,0]
    t1_t2_val = -(t1_t2_val - np.max(t1_t2_val))/(np.max(t1_t2_val) - np.min(t1_t2_val)) #normalizing
    spines = pickle.load(open(PATH + 'spines_89.p','rb')) 
    sln = pickle.load(open(PATH+'sln_matrix.p','rb'))
    #sln = np.ones(fln.shape) 
    clustered_areas = pickle.load(open(PATH + 'clustered_areas.p', 'rb'))
    cognitive_subnetworks = pickle.load(open(PATH + 'cognitive_subnetworks.p', 'rb'))
    #matrices
    fln2 =   fln**gamma
    fln2 = np.einsum('ij,i->ij',fln2, 1/np.sum(fln2,axis =1)) 
    connectivity = dict(
            fln = fln2,
            sln = sln,
            spines = spines, 
            hierarchy = hierarchy, 
            hierarchy_t1t2 = t1_t2_val,
            names_ctx = names_ctx,
            clustered_areas = clustered_areas,
            cognitive_subnetworks = cognitive_subnetworks 
            )
    return connectivity

def names_inds_ctx():
    ''' Names and indexes model'''
    tract = sio.loadmat('connectivity_data/FSe_tractography.mat')
    names = [tract['area_list_Sean_89'][0][l][0] for l in range(89)] 
    names_ctx = []
    inds_full = []
    for l in range(89):
        names_ctx.append(names[l])
        inds_full.append(l)
    return names_ctx, inds_full

# %%
names_ctx,_ = names_inds_ctx()
if True: # saving cognitive subnetworks
    df = pd.read_csv('connectivity_data/lyon_regions_cog_networks_overlap.csv')

    subnet_Visual = []
    subnet_SomMot = []
    subnet_DorsAtt = []
    subnet_Salience = []
    subnet_Limbic = []
    subnet_FPN = []
    subnet_Default = []

    val_Visual = []
    val_SomMot = []
    val_DorsAtt = []
    val_Salience = []
    val_Limbic = []
    val_FPN = []
    val_Default = []


    def add_area_subnet(new_name, i, thres = 0.2):
        val_FPN.append(df['FPN'][i])
        if df['Visual'][i]>thres:
            subnet_Visual.append(names_ctx.index(new_name))
        if df['SomMot'][i]>thres:
            subnet_SomMot.append(names_ctx.index(new_name))
        if df['DorsAtt'][i]>thres:
            subnet_DorsAtt.append(names_ctx.index(new_name))
        if df['Salience'][i]>thres:
            subnet_Salience.append(names_ctx.index(new_name))
        if df['Limbic'][i]>thres:
            subnet_Limbic.append(names_ctx.index(new_name)) 
        if df['FPN'][i]>thres:
            subnet_FPN.append(names_ctx.index(new_name)) 
        if df['Default'][i]>thres:
            subnet_Default.append(names_ctx.index(new_name))
    

    i=0
    for r in list(df['Row']):
        if r in list(names_ctx):
            new_name = r
            add_area_subnet(new_name, i)
        elif r == '7A':
            new_name = '7a'
            add_area_subnet(new_name, i)
        elif r=='7B':
            new_name = '7b'
            add_area_subnet(new_name, i)
        elif r=='ENTORHINAL':
            new_name = 'ENTO'
            add_area_subnet(new_name, i)
        elif r=='INSULA':
            new_name = 'INS'
            add_area_subnet(new_name, i)
        elif r=='Parainsula':
            new_name = 'Pi'
            add_area_subnet(new_name, i)
        elif r=='PERIRHINAL':
            new_name = 'PERI'
            add_area_subnet(new_name, i)
        elif r=='Pro.St':
            new_name = 'Pro.St.'
            add_area_subnet(new_name, i)
        elif r=='TEMPORAL_POLE':
            new_name = 'POLE'
            add_area_subnet(new_name, i)
        elif r=='SUBICULUM':
            print('No SUBICULUM in the 89 areas network')
        elif r=='PIRIFORM':
            print('No PIRIFORM in the 89 areas network')
        i+=1


    subnetworks = dict(Visual = subnet_Visual, 
                    SomMot = subnet_SomMot,
                    DorsAtt =  subnet_DorsAtt, 
                    Salience = subnet_Salience,
                    Limbic = subnet_Limbic,
                    FPN = subnet_FPN,
                    Default = subnet_Default
                    )
    pickle.dump(subnetworks, open('connectivity_data/cognitive_subnetworks.p', 'wb'))

val_FPN = np.array(val_FPN)


fpn_wm = subnetworks['FPN']+[names_ctx.index('LIP')]
areas_surface_fpn = np.zeros(89)
areas_surface_fpn[fpn_wm] = 1
sio.savemat('results/areas_surface_fpn_WM.mat', {'areas_surface_fpn_wm':areas_surface_fpn})
# Out:
# No PIRIFORM in the 89 areas network
# No SUBICULUM in the 89 areas network

# %%
# importing monkey connectivity
connectivity_params = loading_matrices(.3)

#model parameters
modelparams = model_parameters()
modelparams['amp_loc_noise'] = 2.#2.2
modelparams['amp_lr_noise'] = 2.75#3.5
modelparams['amp_loc'] = 2.05#2.1
modelparams['amp_lr'] = 3.4
modelparams['A_spines'] = .4
modelparams['offset_spines'] = .6

#names
names_ctx = connectivity_params['names_ctx']


#creating connectivity
connectivity = CorticalConnectivity(modelparams, connectivity_params)
connectivity.hebbian_symmetric.p_asym = 8
connectivity.hebbian_symmetric.p_sym = 1
inds = []
amp_inds = [(2.2,0)] 
inds.append(fpn_wm)
connectivity.hebbian_symmetric.update_indexes(inds, amp_inds)

# %%
#creating network
modelparams['period'] = 8.
#modelparams['beta'] = 1.9#1.5
#modelparams['h0'] = 1.13#1.1
modelparams['g_p'] = 0
modelparams['beta'] = 2.5#1.5
modelparams['h0'] = 1.13#1.1


task = working_memory_task(modelparams, connectivity)
network = NetworkDynamics(modelparams, connectivity)
network.input_ctx = task.input_current
#network.which_tf = 'sig'

#running dynamics
s0_ctx =  0 * np.random.uniform(0,.1, network.mat.shape[0])
s = 0
amp_in = 10000000
for l in inds[s]:
    Nl = l * connectivity.N
    Nlp1 = (l + 1) * connectivity.N
    s0_ctx[Nl : Nlp1] = amp_in * connectivity.hebbian_symmetric.patterns_current_sym[l, :, s, 0]
results = network.dynamics(s0_ctx)
# Out:
# area =  0
# area =  1
# area =  2
# area =  3
# area =  4
# area =  5
# area =  6
# area =  7
# area =  8
# area =  9
# area =  10
# area =  11
# area =  12
# area =  13
# area =  14
# area =  15
# area =  16
# area =  17
# area =  18
# area =  19
# area =  20
# area =  21
# area =  22
# area =  23
# area =  24
# area =  25
# area =  26
# area =  27
# area =  28
# area =  29
# area =  30
# area =  31
# area =  32
# area =  33
# area =  34
# area =  35
# area =  36
# area =  37
# area =  38
# area =  39
# area =  40
# area =  41
# area =  42
# area =  43
# area =  44
# area =  45
# area =  46
# area =  47
# area =  48
# area =  49
# area =  50
# area =  51
# area =  52
# area =  53
# area =  54
# area =  55
# area =  56
# area =  57
# area =  58
# area =  59
# area =  60
# area =  61
# area =  62
# area =  63
# area =  64
# area =  65
# area =  66
# area =  67
# area =  68
# area =  69
# area =  70
# area =  71
# area =  72
# area =  73
# area =  74
# area =  75
# area =  76
# area =  77
# area =  78
# area =  79
# area =  80
# area =  81
# area =  82
# area =  83
# area =  84
# area =  85
# area =  86
# area =  87
# area =  88
# Simulation t= 0.0
# Simulation t= 0.015
# Simulation t= 0.03
# Simulation t= 0.045
# Simulation t= 0.06
# Simulation t= 0.075
# Simulation t= 0.09
# Simulation t= 0.105
# Simulation t= 0.12
# Simulation t= 0.135
# Simulation t= 0.15
# Simulation t= 0.165
# Simulation t= 0.18
# Simulation t= 0.195
# Simulation t= 0.21
# Simulation t= 0.225
# Simulation t= 0.24
# Simulation t= 0.255
# Simulation t= 0.27
# Simulation t= 0.285
# Simulation t= 0.3
# Simulation t= 0.315
# Simulation t= 0.33
# Simulation t= 0.345
# Simulation t= 0.36
# Simulation t= 0.375
# Simulation t= 0.39
# Simulation t= 0.405
# Simulation t= 0.42
# Simulation t= 0.435
# Simulation t= 0.45
# Simulation t= 0.465
# Simulation t= 0.48
# Simulation t= 0.495
# Simulation t= 0.51
# Simulation t= 0.525
# Simulation t= 0.54
# Simulation t= 0.555
# Simulation t= 0.57
# Simulation t= 0.585
# Simulation t= 0.6
# Simulation t= 0.615
# Simulation t= 0.63
# Simulation t= 0.645
# Simulation t= 0.66
# Simulation t= 0.675
# Simulation t= 0.69
# Simulation t= 0.705
# Simulation t= 0.72
# Simulation t= 0.735
# Simulation t= 0.75
# Simulation t= 0.765
# Simulation t= 0.78
# Simulation t= 0.795
# Simulation t= 0.81
# Simulation t= 0.825
# Simulation t= 0.84
# Simulation t= 0.855
# Simulation t= 0.87
# Simulation t= 0.885
# Simulation t= 0.9
# Simulation t= 0.915
# Simulation t= 0.93
# Simulation t= 0.945
# Simulation t= 0.96
# Simulation t= 0.975
# Simulation t= 0.99
# Simulation t= 1.005
# Simulation t= 1.02
# Simulation t= 1.035
# Simulation t= 1.05
# Simulation t= 1.065
# Simulation t= 1.08
# Simulation t= 1.095
# Simulation t= 1.11
# Simulation t= 1.125
# Simulation t= 1.14
# Simulation t= 1.155
# Simulation t= 1.17
# Simulation t= 1.185
# Simulation t= 1.2
# Simulation t= 1.215
# Simulation t= 1.23
# Simulation t= 1.245
# Simulation t= 1.26
# Simulation t= 1.275
# Simulation t= 1.29
# Simulation t= 1.305
# Simulation t= 1.32
# Simulation t= 1.335
# Simulation t= 1.35
# Simulation t= 1.365
# Simulation t= 1.38
# Simulation t= 1.395
# Simulation t= 1.41
# Simulation t= 1.425
# Simulation t= 1.44
# Simulation t= 1.455
# Simulation t= 1.47
# Simulation t= 1.485
# Simulation t= 1.5
# Simulation t= 1.515
# Simulation t= 1.53
# Simulation t= 1.545
# Simulation t= 1.56
# Simulation t= 1.575
# Simulation t= 1.59
# Simulation t= 1.605
# Simulation t= 1.62
# Simulation t= 1.635
# Simulation t= 1.65
# Simulation t= 1.665
# Simulation t= 1.68
# Simulation t= 1.695
# Simulation t= 1.71
# Simulation t= 1.725
# Simulation t= 1.74
# Simulation t= 1.755
# Simulation t= 1.77
# Simulation t= 1.785
# Simulation t= 1.8
# Simulation t= 1.815
# Simulation t= 1.83
# Simulation t= 1.845
# Simulation t= 1.86
# Simulation t= 1.875
# Simulation t= 1.89
# Simulation t= 1.905
# Simulation t= 1.92
# Simulation t= 1.935
# Simulation t= 1.95
# Simulation t= 1.965
# Simulation t= 1.98
# Simulation t= 1.995
# Simulation t= 2.01
# Simulation t= 2.025
# Simulation t= 2.04
# Simulation t= 2.055
# Simulation t= 2.07
# Simulation t= 2.085
# Simulation t= 2.1
# Simulation t= 2.115
# Simulation t= 2.13
# Simulation t= 2.145
# Simulation t= 2.16
# Simulation t= 2.175
# Simulation t= 2.19
# Simulation t= 2.205
# Simulation t= 2.22
# Simulation t= 2.235
# Simulation t= 2.25
# Simulation t= 2.265
# Simulation t= 2.28
# Simulation t= 2.295
# Simulation t= 2.31
# Simulation t= 2.325
# Simulation t= 2.34
# Simulation t= 2.355
# Simulation t= 2.37
# Simulation t= 2.385
# Simulation t= 2.4
# Simulation t= 2.415
# Simulation t= 2.43
# Simulation t= 2.445
# Simulation t= 2.46
# Simulation t= 2.475
# Simulation t= 2.49
# Simulation t= 2.505
# Simulation t= 2.52
# Simulation t= 2.535
# Simulation t= 2.55
# Simulation t= 2.565
# Simulation t= 2.58
# Simulation t= 2.595
# Simulation t= 2.61
# Simulation t= 2.625
# Simulation t= 2.64
# Simulation t= 2.655
# Simulation t= 2.67
# Simulation t= 2.685
# Simulation t= 2.7
# Simulation t= 2.715
# Simulation t= 2.73
# Simulation t= 2.745
# Simulation t= 2.76
# Simulation t= 2.775
# Simulation t= 2.79
# Simulation t= 2.805
# Simulation t= 2.82
# Simulation t= 2.835
# Simulation t= 2.85
# Simulation t= 2.865
# Simulation t= 2.88
# Simulation t= 2.895
# Simulation t= 2.91
# Simulation t= 2.925
# Simulation t= 2.94
# Simulation t= 2.955
# Simulation t= 2.97
# Simulation t= 2.985
# Simulation t= 3.0
# Simulation t= 3.015
# Simulation t= 3.03
# Simulation t= 3.045
# Simulation t= 3.06
# Simulation t= 3.075
# Simulation t= 3.09
# Simulation t= 3.105
# Simulation t= 3.12
# Simulation t= 3.135
# Simulation t= 3.15
# Simulation t= 3.165
# Simulation t= 3.18
# Simulation t= 3.195
# Simulation t= 3.21
# Simulation t= 3.225
# Simulation t= 3.24
# Simulation t= 3.255
# Simulation t= 3.27
# Simulation t= 3.285
# Simulation t= 3.3
# Simulation t= 3.315
# Simulation t= 3.33
# Simulation t= 3.345
# Simulation t= 3.36
# Simulation t= 3.375
# Simulation t= 3.39
# Simulation t= 3.405
# Simulation t= 3.42
# Simulation t= 3.435
# Simulation t= 3.45
# Simulation t= 3.465
# Simulation t= 3.48
# Simulation t= 3.495
# Simulation t= 3.51
# Simulation t= 3.525
# Simulation t= 3.54
# Simulation t= 3.555
# Simulation t= 3.57
# Simulation t= 3.585
# Simulation t= 3.6
# Simulation t= 3.615
# Simulation t= 3.63
# Simulation t= 3.645
# Simulation t= 3.66
# Simulation t= 3.675
# Simulation t= 3.69
# Simulation t= 3.705
# Simulation t= 3.72
# Simulation t= 3.735
# Simulation t= 3.75
# Simulation t= 3.765
# Simulation t= 3.78
# Simulation t= 3.795
# Simulation t= 3.81
# Simulation t= 3.825
# Simulation t= 3.84
# Simulation t= 3.855
# Simulation t= 3.87
# Simulation t= 3.885
# Simulation t= 3.9
# Simulation t= 3.915
# Simulation t= 3.93
# Simulation t= 3.945
# Simulation t= 3.96
# Simulation t= 3.975
# Simulation t= 3.99
# Simulation t= 4.005
# Simulation t= 4.02
# Simulation t= 4.035
# Simulation t= 4.05
# Simulation t= 4.065
# Simulation t= 4.08
# Simulation t= 4.095
# Simulation t= 4.11
# Simulation t= 4.125
# Simulation t= 4.14
# Simulation t= 4.155
# Simulation t= 4.17
# Simulation t= 4.185
# Simulation t= 4.2
# Simulation t= 4.215
# Simulation t= 4.23
# Simulation t= 4.245
# Simulation t= 4.26
# Simulation t= 4.275
# Simulation t= 4.29
# Simulation t= 4.305
# Simulation t= 4.32
# Simulation t= 4.335
# Simulation t= 4.35
# Simulation t= 4.365
# Simulation t= 4.38
# Simulation t= 4.395
# Simulation t= 4.41
# Simulation t= 4.425
# Simulation t= 4.44
# Simulation t= 4.455
# Simulation t= 4.47
# Simulation t= 4.485
# Simulation t= 4.5
# Simulation t= 4.515
# Simulation t= 4.53
# Simulation t= 4.545
# Simulation t= 4.56
# Simulation t= 4.575
# Simulation t= 4.59
# Simulation t= 4.605
# Simulation t= 4.62
# Simulation t= 4.635
# Simulation t= 4.65
# Simulation t= 4.665
# Simulation t= 4.68
# Simulation t= 4.695
# Simulation t= 4.71
# Simulation t= 4.725
# Simulation t= 4.74
# Simulation t= 4.755
# Simulation t= 4.77
# Simulation t= 4.785
# Simulation t= 4.8
# Simulation t= 4.815
# Simulation t= 4.83
# Simulation t= 4.845
# Simulation t= 4.86
# Simulation t= 4.875
# Simulation t= 4.89
# Simulation t= 4.905
# Simulation t= 4.92
# Simulation t= 4.935
# Simulation t= 4.95
# Simulation t= 4.965
# Simulation t= 4.98
# Simulation t= 4.995
# Simulation t= 5.01
# Simulation t= 5.025
# Simulation t= 5.04
# Simulation t= 5.055
# Simulation t= 5.07
# Simulation t= 5.085
# Simulation t= 5.1
# Simulation t= 5.115
# Simulation t= 5.13
# Simulation t= 5.145
# Simulation t= 5.16
# Simulation t= 5.175
# Simulation t= 5.19
# Simulation t= 5.205
# Simulation t= 5.22
# Simulation t= 5.235
# Simulation t= 5.25
# Simulation t= 5.265
# Simulation t= 5.28
# Simulation t= 5.295
# Simulation t= 5.31
# Simulation t= 5.325
# Simulation t= 5.34
# Simulation t= 5.355
# Simulation t= 5.37
# Simulation t= 5.385
# Simulation t= 5.4
# Simulation t= 5.415
# Simulation t= 5.43
# Simulation t= 5.445
# Simulation t= 5.46
# Simulation t= 5.475
# Simulation t= 5.49
# Simulation t= 5.505
# Simulation t= 5.52
# Simulation t= 5.535
# Simulation t= 5.55
# Simulation t= 5.565
# Simulation t= 5.58
# Simulation t= 5.595
# Simulation t= 5.61
# Simulation t= 5.625
# Simulation t= 5.64
# Simulation t= 5.655
# Simulation t= 5.67
# Simulation t= 5.685
# Simulation t= 5.7
# Simulation t= 5.715
# Simulation t= 5.73
# Simulation t= 5.745
# Simulation t= 5.76
# Simulation t= 5.775
# Simulation t= 5.79
# Simulation t= 5.805
# Simulation t= 5.82
# Simulation t= 5.835
# Simulation t= 5.85
# Simulation t= 5.865
# Simulation t= 5.88
# Simulation t= 5.895
# Simulation t= 5.91
# Simulation t= 5.925
# Simulation t= 5.94
# Simulation t= 5.955
# Simulation t= 5.97
# Simulation t= 5.985
# Simulation t= 6.0
# Simulation t= 6.015
# Simulation t= 6.03
# Simulation t= 6.045
# Simulation t= 6.06
# Simulation t= 6.075
# Simulation t= 6.09
# Simulation t= 6.105
# Simulation t= 6.12
# Simulation t= 6.135
# Simulation t= 6.15
# Simulation t= 6.165
# Simulation t= 6.18
# Simulation t= 6.195
# Simulation t= 6.21
# Simulation t= 6.225
# Simulation t= 6.24
# Simulation t= 6.255
# Simulation t= 6.27
# Simulation t= 6.285
# Simulation t= 6.3
# Simulation t= 6.315
# Simulation t= 6.33
# Simulation t= 6.345
# Simulation t= 6.36
# Simulation t= 6.375
# Simulation t= 6.39
# Simulation t= 6.405
# Simulation t= 6.42
# Simulation t= 6.435
# Simulation t= 6.45
# Simulation t= 6.465
# Simulation t= 6.48
# Simulation t= 6.495
# Simulation t= 6.51
# Simulation t= 6.525
# Simulation t= 6.54
# Simulation t= 6.555
# Simulation t= 6.57
# Simulation t= 6.585
# Simulation t= 6.6
# Simulation t= 6.615
# Simulation t= 6.63
# Simulation t= 6.645
# Simulation t= 6.66
# Simulation t= 6.675
# Simulation t= 6.69
# Simulation t= 6.705
# Simulation t= 6.72
# Simulation t= 6.735
# Simulation t= 6.75
# Simulation t= 6.765
# Simulation t= 6.78
# Simulation t= 6.795
# Simulation t= 6.81
# Simulation t= 6.825
# Simulation t= 6.84
# Simulation t= 6.855
# Simulation t= 6.87
# Simulation t= 6.885
# Simulation t= 6.9
# Simulation t= 6.915
# Simulation t= 6.93
# Simulation t= 6.945
# Simulation t= 6.96
# Simulation t= 6.975
# Simulation t= 6.99
# Simulation t= 7.005
# Simulation t= 7.02
# Simulation t= 7.035
# Simulation t= 7.05
# Simulation t= 7.065
# Simulation t= 7.08
# Simulation t= 7.095
# Simulation t= 7.11
# Simulation t= 7.125
# Simulation t= 7.14
# Simulation t= 7.155
# Simulation t= 7.17
# Simulation t= 7.185
# Simulation t= 7.2
# Simulation t= 7.215
# Simulation t= 7.23
# Simulation t= 7.245
# Simulation t= 7.26
# Simulation t= 7.275
# Simulation t= 7.29
# Simulation t= 7.305
# Simulation t= 7.32
# Simulation t= 7.335
# Simulation t= 7.35
# Simulation t= 7.365
# Simulation t= 7.38
# Simulation t= 7.395
# Simulation t= 7.41
# Simulation t= 7.425
# Simulation t= 7.44
# Simulation t= 7.455
# Simulation t= 7.47
# Simulation t= 7.485
# Simulation t= 7.5
# Simulation t= 7.515
# Simulation t= 7.53
# Simulation t= 7.545
# Simulation t= 7.56
# Simulation t= 7.575
# Simulation t= 7.59
# Simulation t= 7.605
# Simulation t= 7.62
# Simulation t= 7.635
# Simulation t= 7.65
# Simulation t= 7.665
# Simulation t= 7.68
# Simulation t= 7.695
# Simulation t= 7.71
# Simulation t= 7.725
# Simulation t= 7.74
# Simulation t= 7.755
# Simulation t= 7.77
# Simulation t= 7.785
# Simulation t= 7.8
# Simulation t= 7.815
# Simulation t= 7.83
# Simulation t= 7.845
# Simulation t= 7.86
# Simulation t= 7.875
# Simulation t= 7.89
# Simulation t= 7.905
# Simulation t= 7.92
# Simulation t= 7.935
# Simulation t= 7.95
# Simulation t= 7.965
# Simulation t= 7.98
# Simulation t= 7.995

# %%
from cycler import cycler
#results = pickle.load(open('data/gradient_chaos/sim_0.011.p', 'rb'))
time = results['time']
r_ctx = results['rates_ctx']
name_grad = 'figures/S_attractors_rates.pdf'

lw_ov = 2
lw_fr = 3


ov_color = 'blue'
m_fr_color = 'orange'
s_ticks = 24

fs=28
N_block = modelparams['N_block'] # resolution saved nurons 
N_recorded = modelparams['N_recorded'] # resolution saved nurons 
N_neu =int( N_block/int(N_block/N_recorded)) #number recorded neurons
colors = plt.cm.hsv(np.linspace(0,1, N_neu))
names_ctx, inds_full = names_inds_ctx()
dt = modelparams['dt']
t_stop = modelparams['period']
t_end = t_stop



colors_blues = plt.cm.Blues(np.linspace(0,1, N_neu))
colors_reds = plt.cm.Reds(np.linspace(0, 1 , N_neu))
colors_greys = plt.cm.Greys(np.linspace(0, 1 , N_neu))

# plotting altoghether 
fig, ax = plt.subplots(figsize=(26, 16),nrows=9, ncols=10)
fig.tight_layout()
l=0
n_row= 0
for row in ax:
    n_col=0
    for col in row:
        time = np.linspace(0, t_end , r_ctx.shape[0])
        if l<=88:
            ind_1 = l * N_neu
            ind_2 = (l+1) * N_neu
            #col.set_prop_cycle(cycler('color', colors))
            if l in inds[0]:
                color = 'red'
                for k in range(l * N_neu, (l+1)* N_neu, 10):
                    col.plot(time, r_ctx[:, k], lw=lw_fr, color = colors_reds[k - l* N_neu])
            else:
                color = 'grey'
                for k in range(l * N_neu, (l+1)* N_neu, 10):
                    col.plot(time, r_ctx[:, k], lw=lw_fr, color = colors_greys[k - l* N_neu])
            col.set_title(names_ctx[l],fontsize = fs, color = color)
        col.set_ylim([-.1,1.1])
        col.set_xlim([t_end-2, t_end])
        if n_col!=0:
            col.set_yticks([])
            col.set_xticks([])
            col.spines['right'].set_visible(False)
            col.spines['top'].set_visible(False)
            col.spines['left'].set_visible(False)
            col.spines['bottom'].set_visible(False)
        if n_row!=8:
            col.set_xticks([])
            col.set_yticks([])
            col.spines['right'].set_visible(False)
            col.spines['top'].set_visible(False)
            col.spines['left'].set_visible(False)
            col.spines['bottom'].set_visible(False)
        if n_col==0 and n_row==8:
            col.set_ylabel('Activity', fontsize =fs)
            col.set_yticks([0, 1])
            col.set_yticklabels([0, 1], fontsize = s_ticks)
            col.set_xlabel('Time (s)', fontsize = fs)
            col.set_xticks([t_end-2, t_end-1, t_end])
            col.set_xticklabels([0, 1,  2], fontsize = s_ticks)
            col.spines['right'].set_visible(False)
            col.spines['top'].set_visible(False)

        l+=1
        n_col+=1
    n_row+=1
#plt.savefig(name_grad, bbox_inches='tight')

# %%
from cycler import cycler

modelparams = model_parameters()

#results = pickle.load(open('data/gradient_chaos/sim_0.011.p', 'rb'))
time = results['time']
r_ctx = results['rates_ctx']
overlaps = results['overlaps_sym']
#overlaps_choice = results['overlaps_choice']
overlaps_rand = results['overlaps_random']

name_grad = 'figures/S_attractors_overlaps.pdf'

lw_ov = 3
lw_fr = 3


ov_color = 'blue'
m_fr_color = 'orange'
s_ticks = 24

fs=28

N_block = modelparams['N_block']
p = overlaps.shape[2]
colors = plt.cm.hsv(np.linspace(0,1,N_block))
names_ctx, inds_full = names_inds_ctx()
dt = modelparams['dt']
t_end = overlaps.shape[0] * dt
t_stop = t_end
time = np.linspace(0, t_end , overlaps.shape[0])
colors = ['b', 'r']
fig, ax = plt.subplots(figsize=(26, 16),nrows=9, ncols=10)
fig.tight_layout()
l=0
n_row= 0
for row in ax:
    n_col=0
    for col in row:
        if l<89:
            #for s in range(p):
            if l in inds[0]:
                color = 'red'
            else:
                color = 'grey'
            col.plot(time, overlaps[:, l, 0], lw =lw_ov, color = 'blue')
            col.set_title(names_ctx[l],fontsize = fs, color = color)
            axij = col.twinx()
            r_mean = np.mean(r_ctx[:, l * N_neu: (l + 1)* N_neu], axis = 1)
            axij.plot(time,  r_mean, color = m_fr_color, lw= lw_ov)
            axij.set_ylim([0,.5])
        col.set_ylim([-.1,0.5])
        col.set_xlim([t_end - 2, t_end])
        col.axhline(y=0, xmin=0, xmax=400, ls = '--',color='gray')
        if n_col!=0:
            col.set_yticks([])
            col.set_xticks([])
            col.spines['right'].set_visible(False)
            col.spines['top'].set_visible(False)
            col.spines['left'].set_visible(False)
            col.spines['bottom'].set_visible(False)
        if n_row!=9:
            col.set_xticks([])
            col.set_yticks([])
            col.spines['right'].set_visible(False)
            col.spines['top'].set_visible(False)
            col.spines['left'].set_visible(False)
            col.spines['bottom'].set_visible(False)
            axij.set_xticks([])
            axij.set_yticks([])
            axij.spines['right'].set_visible(False)
            axij.spines['top'].set_visible(False)
            axij.spines['left'].set_visible(False)
            axij.spines['bottom'].set_visible(False)
        if n_col==0 and n_row==8:
            col.set_ylabel('Overlap', fontsize =fs)
            col.set_yticks([0, 0.5])
            col.set_yticklabels([0, 0.5], fontsize = s_ticks)
            col.set_xlabel('Time (s)', fontsize = fs)
            col.set_xticks([t_end-2, t_end-1, t_end])
            col.set_xticklabels([0, 1,  2], fontsize = s_ticks)
            col.spines['right'].set_visible(False)
            col.spines['top'].set_visible(False)
        if n_col != 9:
            axij.spines['right'].set_visible(False)
            axij.spines['top'].set_visible(False)
            axij.spines['left'].set_visible(False)
            axij.spines['bottom'].set_visible(False)
            axij.set_yticks([])
        if n_col==8 and n_row==8:
            axij.set_yticks([0, 0.2, 0.4])
            axij.set_yticklabels([0, 0.2, 0.4], fontsize = s_ticks)
            axij.set_ylabel('Activity', fontsize =fs)
            col.plot(time, -20 * time -1, lw =lw_ov, color = 'blue')
            axij = col.twinx()
            axij.plot(time,  -20 * time - 1, color = m_fr_color, lw= lw_ov)
            col.set_ylim([-.1,0.5])
            axij.set_ylim([0,.5])
            axij.spines['top'].set_visible(False)
            axij.spines['left'].set_visible(False)
            axij.spines['bottom'].set_visible(False)
            col.spines['top'].set_visible(False)
            col.spines['left'].set_visible(False)
            col.spines['bottom'].set_visible(False)
            col.set_xticks([])
            col.set_yticks([])
            col.set_xlabel('', fontsize = fs)
 
            
        l+=1
        n_col+=1
    n_row+=1
#plt.savefig(str_ov, bbox_inches='tight')
#plt.close()
plt.savefig(name_grad, bbox_inches='tight')

# %%
time = results['time']
r_ctx = results['rates_ctx']
overlaps = results['overlaps_sym']


ov_color = 'blue'
m_fr_color = 'orange'
s_ticks = 28
lw_fr = 3 
lw_ov = 3

dt = modelparams['dt']
t_end = modelparams['period']
time = np.linspace(0, t_end , r_ctx.shape[0])


colors_blues = plt.cm.Blues(np.linspace(0,1, N_neu))
colors_reds = plt.cm.Reds(np.linspace(0, 1 , N_neu))
colors_greys = plt.cm.Greys(np.linspace(0, 1 , N_neu))

fig, ax = plt.subplots(figsize=(28, 4),nrows=2, ncols=6)

dN = 10
#frist column
ind1 = names_ctx.index('9/46d')
for l in range(ind1* N_neu, (ind1+1)* N_neu, dN):
    ax[0,0].plot(time, r_ctx[:, l], color = colors_reds[l-ind1* N_neu], lw= lw_fr)
ax[0,0].set_ylim([0,1.1])
ax[0,0].set_xticks([])
ax[0,0].spines['right'].set_visible(False)
ax[0,0].spines['top'].set_visible(False)
ax[0,0].spines['bottom'].set_visible(False)
ax[0,0].set_xlim([t_end - 2, t_end])
ax[0,0].set_yticks([0, 0.5, 1])
ax[0,0].set_yticklabels([0, 0.5, 1], fontsize = s_ticks)

ax[1,0].plot(time, overlaps[:, ind1, 0], color = ov_color, lw= lw_ov)
ax[1,0].set_ylim([-.1,0.5])
ax[1,0].set_xlim([t_end - 2, t_end])
ax[1,0].spines['right'].set_visible(False)
ax[1,0].spines['top'].set_visible(False)
ax[1,0].set_xticks([t_end - 2, t_end-1, t_end])
ax[1,0].set_xticklabels([t_end - 2, t_end-1, t_end], fontsize = s_ticks)
ax[1,0].set_yticks([0, 0.2, 0.4])
ax[1,0].set_yticklabels([0, 0.2, 0.4], fontsize = s_ticks)
ax[1,0].axhline(y=0, xmin=0, xmax=400, ls = '--',color='gray')

ax10 = ax[1,0].twinx()
r_mean1 = np.mean(r_ctx[:, ind1* N_neu: (ind1+1)* N_neu], axis = 1)
ax10.plot(time,  r_mean1, color = m_fr_color, lw= lw_ov)
ax10.set_ylim([0,0.5])
ax10.set_xlim([t_end - 2, t_end])
ax10.set_xticks([t_end - 2, t_end-1, t_end])
ax10.set_xticklabels([0, 1, 2], fontsize = s_ticks)
ax10.spines['right'].set_visible(False)
ax10.spines['top'].set_visible(False)
ax10.set_yticks([])


#second column

ind2 = names_ctx.index('8l')
for l in range(ind2* N_neu, (ind2+1)* N_neu, dN):
    ax[0,1].plot(time, r_ctx[:, l],  color = colors_reds[l - ind2* N_neu], lw= lw_fr)
ax[0,1].set_ylim([0,1.1])
ax[0,1].set_xticks([])
ax[0, 1].spines['right'].set_visible(False)
ax[0, 1].spines['top'].set_visible(False)
ax[0, 1].spines['left'].set_visible(False)
ax[0, 1].spines['bottom'].set_visible(False)
ax[0, 1].set_xlim([t_end - 2, t_end])
ax[0, 1].set_yticks([])

ax[1,1].plot(time, overlaps[:, ind2, 0], color = ov_color, lw= lw_ov)
ax[1,1].set_ylim([-.1,0.5])
ax[1,1].set_xlim([t_end - 2, t_end])
ax[1,1].spines['right'].set_visible(False)
ax[1,1].spines['top'].set_visible(False)
ax[1,1].spines['left'].set_visible(False)
ax[1,1].spines['bottom'].set_visible(False)
ax[1,1].set_yticks([])
ax[1,1].set_xticks([])
#ax[1,1].set_xticks([t_end - 2, t_end-1, t_end])
#ax[1,1].set_xticklabels([t_end - 2, t_end-1, t_end], fontsize = s_ticks)
ax[1,1].axhline(y=0, xmin=0, xmax=400, ls = '--',color='gray')

ax11 = ax[1,1].twinx()
r_mean = np.mean(r_ctx[:, ind2 * N_neu: (ind2+1) * N_neu], axis = 1)
ax11.plot(time,  r_mean, color = m_fr_color, lw= lw_ov)
ax11.set_ylim([0,0.5])
ax11.set_xlim([t_end - 2, t_end])
ax11.set_xticks([])
#ax11.set_xticks([t_end - 2, t_end-1, t_end])
#ax11.set_xticklabels([0, 1, 2], fontsize = s_ticks)
ax11.spines['right'].set_visible(False)
ax11.spines['top'].set_visible(False)
ax11.spines['left'].set_visible(False)
ax11.spines['bottom'].set_visible(False)
ax11.set_yticks([])

#third column

ind3 = names_ctx.index('7a')
for l in range(ind3* N_neu, (ind3+1)* N_neu, dN):
    ax[0,2].plot(time, r_ctx[:, l], color = colors_reds[l-ind3* N_neu], lw=lw_fr)
ax[0,2].set_ylim([0,1.1])
ax[0,2].set_xticks([])
ax[0,2].spines['right'].set_visible(False)
ax[0,2].spines['top'].set_visible(False)
ax[0,2].spines['left'].set_visible(False)
ax[0,2].spines['bottom'].set_visible(False)
ax[0,2].set_xlim([t_end - 2, t_end])
ax[0,2].set_yticks([])

ax[1,2].plot(time, overlaps[:, ind3, 0], color = ov_color, lw= lw_ov)
ax[1,2].set_ylim([-.1,0.5])
ax[1,2].set_xlim([t_end - 2, t_end])
ax[1,2].spines['right'].set_visible(False)
ax[1,2].spines['top'].set_visible(False)
ax[1,2].spines['left'].set_visible(False)
ax[1,2].spines['bottom'].set_visible(False)
ax[1,2].set_yticks([])
ax[1,2].set_xticks([])
#ax[1,2].set_xticks([t_end - 2, t_end])
#ax[1,2].set_xticklabels([t_end - 2, t_end], fontsize = s_ticks)
ax[1,2].axhline(y=0, xmin=0, xmax=400, ls = '--',color='gray')

ax12 = ax[1,2].twinx()
r_mean = np.mean(r_ctx[:, ind3* N_neu: (ind3+1)* N_neu], axis = 1)
ax12.plot(time,  r_mean, color = m_fr_color, lw= lw_ov)
ax12.set_ylim([0,.5])
ax12.set_xlim([t_end - 2, t_end])
ax12.set_xticks([])
#ax12.set_xticks([t_end - 2, t_end-1, t_end])
#ax12.set_xticklabels([0, 1, 2], fontsize = s_ticks)
#ax12.spines['right'].set_visible(False)
ax12.spines['top'].set_visible(False)
ax12.spines['left'].set_visible(False)
ax12.spines['right'].set_visible(False)
ax12.spines['bottom'].set_visible(False)
ax12.set_yticks([])
#ax12.set_yticklabels([0, 0.2, 0.4], fontsize = s_ticks)


#4th column

ind3 = names_ctx.index('LIP')
for l in range(ind3* N_neu, (ind3+1)* N_neu, dN):
    ax[0,3].plot(time, r_ctx[:, l], color = colors_reds[l-ind3* N_neu], lw=lw_fr)
ax[0,3].set_ylim([0,1.1])
ax[0,3].set_xticks([])
ax[0,3].spines['right'].set_visible(False)
ax[0,3].spines['top'].set_visible(False)
ax[0,3].spines['left'].set_visible(False)
ax[0,3].spines['bottom'].set_visible(False)
ax[0,3].set_xlim([t_end - 2, t_end])
ax[0,3].set_yticks([])

ax[1,3].plot(time, overlaps[:, ind3, 0], color = ov_color, lw= lw_ov)
ax[1,3].set_ylim([-.1,0.5])
ax[1,3].set_xlim([t_end - 2, t_end])
ax[1,3].spines['right'].set_visible(False)
ax[1,3].spines['top'].set_visible(False)
ax[1,3].spines['left'].set_visible(False)
ax[1,3].spines['bottom'].set_visible(False)
ax[1,3].set_yticks([])
ax[1,3].set_xticks([])
#ax[1,3].set_xticks([t_end - 2, t_end])
#ax[1,3].set_xticklabels([t_end - 2, t_end], fontsize = s_ticks)
ax[1,3].axhline(y=0, xmin=0, xmax=400, ls = '--',color='gray')

ax13 = ax[1,3].twinx()
r_mean = np.mean(r_ctx[:, ind3* N_neu: (ind3+1)* N_neu], axis = 1)
ax13.plot(time,  r_mean, color = m_fr_color, lw= lw_ov)
ax13.set_ylim([0,.5])
ax13.set_xticks([])
#ax13.set_xlim([t_end - 2, t_end])
#ax13.set_xticks([t_end - 2, t_end-1, t_end])
#ax13.set_xticklabels([0, 1, 2], fontsize = s_ticks)
ax13.spines['top'].set_visible(False)
ax13.spines['left'].set_visible(False)
ax13.spines['right'].set_visible(False)
ax13.spines['bottom'].set_visible(False)
ax13.set_yticks([])


#5th column

ind3 = names_ctx.index('MT')
for l in range(ind3* N_neu, (ind3+1)* N_neu, dN):
    ax[0,4].plot(time, r_ctx[:, l], color = colors_greys[l-ind3* N_neu], lw=lw_fr)
ax[0,4].set_ylim([0,1.1])
ax[0,4].set_xticks([])
ax[0,4].spines['right'].set_visible(False)
ax[0,4].spines['top'].set_visible(False)
ax[0,4].spines['left'].set_visible(False)
ax[0,4].spines['bottom'].set_visible(False)
ax[0,4].set_xlim([t_end - 2, t_end])
ax[0,4].set_yticks([])

ax[1,4].plot(time, overlaps[:, ind3, 0], color = ov_color, lw= lw_ov)
ax[1,4].set_ylim([-.1,0.5])
ax[1,4].set_xlim([t_end - 2, t_end])
ax[1,4].spines['right'].set_visible(False)
ax[1,4].spines['top'].set_visible(False)
ax[1,4].spines['left'].set_visible(False)
ax[1, 4].spines['bottom'].set_visible(False)
ax[1,4].set_yticks([])
ax[1,4].set_xticks([])
#ax[1,4].set_xticks([t_end - 2, t_end])
#ax[1,4].set_xticklabels([t_end - 2, t_end], fontsize = s_ticks)
ax[1,4].axhline(y=0, xmin=0, xmax=400, ls = '--',color='gray')

ax14 = ax[1,4].twinx()
r_mean = np.mean(r_ctx[:, ind3* N_neu: (ind3+1)* N_neu], axis = 1)
ax14.plot(time,  r_mean, color = m_fr_color, lw= lw_ov)
ax14.set_ylim([0,.5])
ax14.set_xlim([t_end - 2, t_end])
ax14.set_xticks([t_end - 2, t_end-1, t_end])
ax14.set_xticklabels([0, 1, 2], fontsize = s_ticks)
#ax12.spines['right'].set_visible(False)
ax14.spines['top'].set_visible(False)
ax14.spines['left'].set_visible(False)
ax14.set_yticks([])
ax14.set_xticks([])
#ax14.set_yticks([0, 0.2, 0.4])
#ax14.set_yticklabels([0, 0.2, 0.4], fontsize = s_ticks)
ax14.spines['right'].set_visible(False)
ax14.spines['bottom'].set_visible(False)

#6th column
ind = names_ctx.index('TEO')
for l in range(ind * N_neu, (ind + 1)* N_neu, dN):
    ax[0,5].plot(time, r_ctx[:, l], color = colors_greys[l-ind* N_neu], lw=lw_fr)
ax[0,5].set_ylim([0,1.1])
ax[0,5].set_xticks([])
ax[0,5].spines['right'].set_visible(False)
ax[0,5].spines['top'].set_visible(False)
ax[0,5].spines['left'].set_visible(False)
ax[0,5].spines['bottom'].set_visible(False)
ax[0,5].set_xlim([t_end - 2, t_end])
ax[0,5].set_yticks([])


ax[1,5].plot(time, overlaps[:, ind3, 0], color = ov_color, lw= lw_ov)
ax[1,5].set_ylim([-.1,0.5])
ax[1,5].set_xlim([t_end - 2, t_end])
ax[1,5].spines['right'].set_visible(False)
ax[1,5].spines['top'].set_visible(False)
ax[1,5].spines['left'].set_visible(False)
ax[1,5].spines['bottom'].set_visible(False)
ax[1,5].set_yticks([])
#ax[1,5].set_xticks([t_end - 2, t_end])
#ax[1,5].set_xticklabels([t_end - 2, t_end], fontsize = s_ticks)
ax[1, 5].set_xticks([])
ax[1,5].axhline(y=0, xmin=0, xmax=400, ls = '--',color='gray')

ax15 = ax[1,5].twinx()
r_mean = np.mean(r_ctx[:, ind * N_neu: (ind + 1)* N_neu], axis = 1)
ax15.plot(time,  r_mean, color = m_fr_color, lw= lw_ov)
ax15.set_ylim([0,.5])
#ax15.set_xlim([t_end - 2, t_end])
#ax15.set_xticks([t_end - 2, t_end-1, t_end])
#ax15.set_xticklabels([0, 1, 2], fontsize = s_ticks)
ax15.set_xticks([])
#ax12.spines['right'].set_visible(False)
ax15.spines['top'].set_visible(False)
ax15.spines['left'].set_visible(False)
ax15.spines['bottom'].set_visible(False)
ax15.set_yticks([0, 0.2, 0.4])
ax15.set_yticklabels([0, 0.2, 0.4], fontsize = s_ticks)

plt.savefig('figures/panels/attractors.pdf', bbox_inches='tight')

# %%
#saving results for display at the surface
if True:
    #save as mat file
    overlaps = results['overlaps_sym'][:,:,0,0]
    sio.savemat('results/overlaps_fpn_wm.mat', {'overlaps_fpn_wm':overlaps})
    r_ctx = results['rates_ctx']
    N_block = modelparams['N_block'] # resolution saved nurons 
    N_recorded = modelparams['N_recorded'] # resolution saved nurons 
    N_neu =int( N_block/int(N_block/N_recorded)) #number recorded neurons
    mean_rates = []
    for l in range(89):
        r_mean = np.mean(r_ctx[:, l * N_neu: (l + 1)* N_neu], axis = 1)
        mean_rates.append(r_mean)
    mean_rates = np.array(mean_rates)
    sio.savemat('results/mean_rate_fpn_wm.mat', {'rate_fpn_wm':mean_rates})
